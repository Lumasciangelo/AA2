# %% [markdown]
# Importamos librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import matplotlib.colors as mcolors
import os

# %% [markdown]
# Establecemos GPU

# %%
# Configurar para que TensorFlow utilice la GPU por defecto
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Configurar para que TensorFlow asigne memoria dinámicamente
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        # Especificar la GPU por defecto
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Manejar error
        print(e)

# %% [markdown]
# Importamos data set

# %%
REPO_URL = "https://github.com/Lumasciangelo/AA2.git"
SUBDIR = "Ejercicio_1"
REPO_NAME = "AA2"

if SUBDIR not in os.getcwd():
    if not os.path.exists(REPO_NAME):
        # Inicializar el repositorio vacío
        # !git clone --depth 1 --filter=blob:none --sparse {REPO_URL}
        os.chdir(REPO_NAME)
        # Activar el modo sparse-checkout y obtener solo el subdirectorio
        # !git sparse-checkout init --cone
        # !git sparse-checkout set {SUBDIR}
    os.chdir(SUBDIR)
# Out:
# Cloning into 'AA2'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 25 (delta 0), reused 25 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 579.46 KiB | 2.42 MiB/s, done.
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 1 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (1/1), 47.09 KiB | 3.62 MiB/s, done.

# %% [markdown]
# Cargamos y visualizamos los datos

# %%
data = pd.read_csv('Student_Performance.csv')
print(data.head())
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %% [markdown]
# vemos si hay nulos y de que tipo es cada variable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %% [markdown]
# Pasamos la variable actividades extracurriculares a dummy: "Yes" : 1, "No" : 0

# %%
data['Extracurricular Activities'] = data['Extracurricular Activities'].map({'Yes': 1, 'No': 0})

# %% [markdown]
# Vemos algunas estadísticas de nuestras variables

# %%
data.describe()
# Out:
#        Hours Studied  Previous Scores  Extracurricular Activities  \
# count   10000.000000     10000.000000                10000.000000
# mean        4.992900        69.445700                    0.494800
# std         2.589309        17.343152                    0.499998
# min         1.000000        40.000000                    0.000000
# 25%         3.000000        54.000000                    0.000000
# 50%         5.000000        69.000000                    0.000000
# 75%         7.000000        85.000000                    1.000000
# max         9.000000        99.000000                    1.000000
#
#         Sleep Hours  Sample Question Papers Practiced  Performance Index
# count  10000.000000                      10000.000000       10000.000000
# mean       6.530600                          4.583300          55.224800
# std        1.695863                          2.867348          19.212558
# min        4.000000                          0.000000          10.000000
# 25%        5.000000                          2.000000          40.000000
# 50%        7.000000                          5.000000          55.000000
# 75%        8.000000                          7.000000          71.000000
# max        9.000000                          9.000000         100.000000

# %% [markdown]
# Estandarizamos las variables

# %%
# Utilizamos el método Z score con la librería StandardScaler porque en su fórmula tiene en cuenta la varianza,
# ya que notamos que algunas de nuestras variables tienen una varianza muy alta
df_sub = data
df_std = (df_sub-df_sub.mean())/df_sub.std()

# %% [markdown]
# Vemos la distribución de las variables

# %%
#Distribución de variables
sns.boxplot(data = df_std)
plt.xticks(rotation= 45)
plt.show()

# %% [markdown]
# Definimos nuestro modelo

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    #tf.keras.layers.Dense(units=10, activation='sigmoid'),
    tf.keras.layers.Dense(units=1, activation='linear')
])

# %% [markdown]
# Separamos en train y test y entrenamos el modelo

# %%
x = df_std.drop(['Performance Index'], axis = 1)
y = df_std['Performance Index']
#print(x.shape)
#print(y.shape)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.05)
model.compile(optimizer=optimizer, loss='mae')
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2172 - val_loss: 0.0971
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0950 - val_loss: 0.0928
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0948 - val_loss: 0.0967
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0978 - val_loss: 0.0895
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0913 - val_loss: 0.0958
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0954 - val_loss: 0.0991
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0934 - val_loss: 0.0936
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0963 - val_loss: 0.0901
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0940 - val_loss: 0.0926
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0935 - val_loss: 0.0889
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0934 - val_loss: 0.0961
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0952 - val_loss: 0.0982
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0944 - val_loss: 0.1053
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0973 - val_loss: 0.0964
# Epoch 16/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0953 - val_loss: 0.0927
# Epoch 17/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0949 - val_loss: 0.0889
# Epoch 18/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0950 - val_loss: 0.0964
# Epoch 19/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0969 - val_loss: 0.0953
# Epoch 20/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0944 - val_loss: 0.0916
# Epoch 21/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0938 - val_loss: 0.0964
# Epoch 22/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0950 - val_loss: 0.1025
# Epoch 23/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0967 - val_loss: 0.0898
# Epoch 24/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0955 - val_loss: 0.1025
# Epoch 25/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0965 - val_loss: 0.0970
# Epoch 26/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0992 - val_loss: 0.0951
# Epoch 27/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0975 - val_loss: 0.0940
# Epoch 28/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0942 - val_loss: 0.0876
# Epoch 29/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0951 - val_loss: 0.1043
# Epoch 30/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0958 - val_loss: 0.0945
# Epoch 31/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0948 - val_loss: 0.0885
# Epoch 32/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0947 - val_loss: 0.0908
# Epoch 33/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0984 - val_loss: 0.0928
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0946 - val_loss: 0.0899
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0949 - val_loss: 0.0866
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0960 - val_loss: 0.0853
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0927 - val_loss: 0.1012
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0971 - val_loss: 0.0924
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0943 - val_loss: 0.0982
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0957 - val_loss: 0.0908
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0946 - val_loss: 0.0893
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0937 - val_loss: 0.1134
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0991 - val_loss: 0.0983
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0947 - val_loss: 0.0899
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0928 - val_loss: 0.0903
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0949 - val_loss: 0.0874
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0934 - val_loss: 0.0924
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0920 - val_loss: 0.0927
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0989 - val_loss: 0.1014
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0957 - val_loss: 0.0966

# %% [markdown]
# Probamos varios modelos diferentes:
#
# *   agregando una capa oculta con 20 neuronas y activacion relu que nos dio un mae en train de 0.0976 mientras que en test nos dio un mae de 1.1119, es decir que el modelo está overfiteando
# *   agregando una capa oculta con 10 neuronas y activacion sigmoide que nos dio un mae en train de 0.0923 mientras que en test nos dio un mae de 0.1031, es decir que el modelo sigue overfiteando pero un poco menos
# *   Por último probamos sacando las capas ocultas y obtuvimos un mae en train de 0.0951 mientras que en test nos dio un mae de 0.0966, por lo tanto nos vamos a quedar con este modelo

# %% [markdown]
# También miramos la correlación lineal que hay entre las variables

# %%
matriz = data.corr()
sns.heatmap(matriz, annot=True)
plt.show()

# %% [markdown]
# Observamos que nuestra variable respuesta (Performance Index) tiene muy poca correlación con las variables "Extracurricular Activities", "Sleep Hours", "Sample Question Papers Practiced", por ende vamos a probar sacandolas de nuestro modelo para ver que ocurre.

# %% [markdown]
# Definimos un nuevo modelo

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),
    #tf.keras.layers.Dense(units=10, activation='sigmoid'),
    tf.keras.layers.Dense(units=1, activation='linear')
])

# %% [markdown]
# Separamos en train y test y entrenamos el modelo

# %%
x = df_std[['Hours Studied','Previous Scores']]
y = df_std['Performance Index']
#print(x.shape)
#print(y.shape)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.05)
model2.compile(optimizer=optimizer, loss='mae')
model2.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0990 - val_loss: 0.1004
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1015 - val_loss: 0.0998
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0975 - val_loss: 0.1046
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1001 - val_loss: 0.0961
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0998 - val_loss: 0.0983
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0998 - val_loss: 0.1067
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0991 - val_loss: 0.0957
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1018 - val_loss: 0.1055
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0997 - val_loss: 0.1043
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0996 - val_loss: 0.1018
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1014 - val_loss: 0.0974
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1023 - val_loss: 0.1039
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1001 - val_loss: 0.0973
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0979 - val_loss: 0.0954
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0998 - val_loss: 0.0962
# Epoch 16/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1023 - val_loss: 0.0961
# Epoch 17/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1045 - val_loss: 0.1035
# Epoch 18/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1010 - val_loss: 0.0962
# Epoch 19/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0979 - val_loss: 0.0956
# Epoch 20/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1017 - val_loss: 0.0958
# Epoch 21/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0990 - val_loss: 0.1043
# Epoch 22/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0995 - val_loss: 0.1014
# Epoch 23/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0977 - val_loss: 0.0985
# Epoch 24/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1022 - val_loss: 0.1015
# Epoch 25/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0996 - val_loss: 0.0967
# Epoch 26/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0996 - val_loss: 0.0958
# Epoch 27/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0988 - val_loss: 0.0948
# Epoch 28/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1007 - val_loss: 0.0986
# Epoch 29/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0992 - val_loss: 0.1023
# Epoch 30/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0988 - val_loss: 0.1028
# Epoch 31/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0997 - val_loss: 0.1019
# Epoch 32/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0984 - val_loss: 0.0984
# Epoch 33/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1032 - val_loss: 0.1148
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1006 - val_loss: 0.1007
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0985 - val_loss: 0.0990
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1000 - val_loss: 0.1008
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0990 - val_loss: 0.0990
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1003 - val_loss: 0.0961
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0993 - val_loss: 0.0992
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0998 - val_loss: 0.1045
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1022 - val_loss: 0.0956
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0983 - val_loss: 0.1085
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1028 - val_loss: 0.1003
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0986 - val_loss: 0.1101
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1026 - val_loss: 0.0973
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0997 - val_loss: 0.0996
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0994 - val_loss: 0.0998
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1000 - val_loss: 0.1047
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0983 - val_loss: 0.0962
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1016 - val_loss: 0.1005

# %% [markdown]
# En este modelo nuevo obtuvimos un mae en train de 0.1016 y en test de 0.1005, por ende nos quedaríamos con este nuevo modelo que tiene solo como variables explicativas "Hours Studied" y "Previous Scores", ya que no difiere significativamente del modelo anterior y tiene menos parámetros.

# %%
X1 = df_std['Hours Studied'].to_numpy()
X2 = df_std['Previous Scores'].to_numpy()
Y = df_std['Performance Index'].to_numpy()

# %% [markdown]
# Definimos una función para plotear la frontera de decisión sobre los datos.

# %%
def plot_results(X1, X2, Y, model):
    plt.xlabel('Hours Studied')
    plt.ylabel('Previous Scores')
    x1 = np.linspace(-2, 2, 200)
    x2 = np.linspace(-2, 2, 200)
    x1, x2 = np.meshgrid(x1, x2, indexing='ij')
    x = np.array([x1.ravel(), x2.ravel()]).T
    y = model.predict(x).reshape(x1.shape)
    norm = mcolors.Normalize(vmin=min(Y), vmax=max(Y))
    plt.imshow(y, extent=(-2, 2, -2, 2), origin='lower', cmap='viridis', alpha=1, norm = norm)
    plt.scatter(X1, X2, c=Y, cmap='viridis', edgecolor='k', s=50, norm = norm)
    plt.colorbar()
    plt.xlim(-2, 2)
    plt.ylim(-2, 2)
    plt.show()

# %% [markdown]
# Ploteamos los resultados

# %%
plot_results(X1, X2, Y, model2)
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
